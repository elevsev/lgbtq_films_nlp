# %%
from bs4 import BeautifulSoup
import requests, openpyxl
import pandas as pd

# %%
# https://www.youtube.com/watch?v=qNfxUsQ70QU&ab_channel=MattBarty
# https://www.imdb.com/title/tt0096697/episodes?season=1

# %%
def retrive_web_data(url):
    '''Returns the HTML doc string associated with the url provided.'''
    response = requests.get(url)
    season_page = BeautifulSoup(response.content)
    episode_tile = season_page.findAll('div', attrs={'class': 'info'})
    return episode_tile

# %%
retrive_web_data(url='https://www.imdb.com/title/tt0096697/episodes?season=1')
# Out:
# [<div class="info" itemprop="episodes" itemscope="" itemtype="http://schema.org/TVEpisode">
#      <meta content="1" itemprop="episodeNumber"/>
#      <div class="airdate">
#              2 Sep. 1990
#      </div>
#      <strong><a href="/title/tt0348034/" itemprop="name" title="Simpsons Roasting on an Open Fire">Simpsons Roasting on an Open Fire</a></strong>
#      <div class="ipl-rating-widget">
#      <div class="ipl-rating-star small">
#          <span class="ipl-rating-star__star">
#              <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M0 0h24v24H0z" fill="none"></path>
#                  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#                  <path d="M0 0h24v24H0z" fill="none"></path>
#              </svg>
#          </span>
#          <span class="ipl-rating-star__rating">8.2</span>
# ...

# %%
# url = 'https://www.imdb.com/title/tt0096697/episodes?season=1'
# response = requests.get(url)
# season_page = BeautifulSoup(response.content)
# episode_tile = season_page.findAll('div', attrs={'class': 'info'})

# %%
season_no_list = []
episode_no_list = []
episode_name_list = []
episode_airdate_list = []
episode_score_list = []
episode_votes_list = []

# %%
for season in range(3):
    season_no = season + 1

    print(f'--- Season: {season_no} ---')

    url = f'https://www.imdb.com/title/tt0096697/episodes?season={season_no}'

    response = requests.get(url)
    season_page = BeautifulSoup(response.content)
    episode_tile = season_page.findAll('div', attrs={'class': 'info'})

    for episode_no, episode in enumerate(episode_tile):

        episode_name = episode.strong.a.text
        print(episode_name)

        episode_airdate = episode.find('div', attrs={'class': 'airdate'}).text.strip().replace('.', '')
        print(episode_airdate)

        episode_score = episode.find(
            'div', attrs={'class': 'ipl-rating-widget'}
        ).find(
            'div',attrs={'class': 'ipl-rating-star small'}
        ).find(
            'span', attrs={'class': 'ipl-rating-star__rating'}).text
        print(episode_score)

        episode_votes = episode.find(
            'div', attrs={'class': 'ipl-rating-widget'}
        ).find(
            'div',attrs={'class': 'ipl-rating-star small'}
        ).find(
            'span', attrs={'class': 'ipl-rating-star__total-votes'}
            ).text.strip('()').replace(',','')
        print(episode_votes)

        print('\n')

        season_no_list.append(season_no)
        episode_no_list.append(episode_no + 1)
        episode_airdate_list.append(episode_airdate)
        episode_name_list.append(episode_name)
        episode_score_list.append(episode_score)
        episode_votes_list.append(episode_votes)

    print('----- DONE -----')
# Out:
# --- Season: 1 ---
# Simpsons Roasting on an Open Fire
# 2 Sep 1990
# 8.2
# 7179
#
#
# Bart the Genius
# 14 Jan 1990
# 7.7
# 4719
#
#
# Homer's Odyssey
# 21 Jan 1990
# 7.4
# 4154
#
#
# There's No Disgrace Like Home
# 28 Jan 1990
# 7.7
# 4095
#
#
# Bart the General
# 4 Feb 1990
# 8.0
# 4435
#
#
# Moaning Lisa
# 11 Feb 1990
# 7.7
# 3978
#
#
# The Call of the Simpsons
# 2 Sep 1990
# 7.8
# 3859
#
#
# The Telltale Head
# 25 Feb 1990
# 7.7
# 3709
#
#
# Life on the Fast Lane
# 18 Mar 1990
# 7.5
# 3679
#
#
# Homer's Night Out
# 7 Apr 1991
# 7.4
# 3570
#
#
# The Crepes of Wrath
# 15 Apr 1990
# 7.8
# 3631
#
#
# Krusty Gets Busted
# 17 Mar 1991
# 8.4
# 4005
#
#
# Some Enchanted Evening
# 13 May 1990
# 7.7
# 3959
#
#
# ----- DONE -----
# --- Season: 2 ---
# Bart Gets an F
# 11 Oct 1990
# 8.3
# 3987
#
#
# Simpson and Delilah
# 18 Oct 1990
# 8.2
# 4103
#
#
# Treehouse of Horror
# 19 Nov 1991
# 8.3
# 4224
#
#
# Two Cars in Every Garage and Three Eyes on Every Fish
# 1 Nov 1990
# 8.1
# 3460
#
#
# ...

# %%
        season_no_list.append(season_no)
        episode_no_list.append(episode_no + 1)
        episode_airdate_list.append(episode_airdate)
        episode_name_list.append(episode_name)
        episode_score_list.append(episode_score)
        episode_votes_list.append(episode_votes)

# %%
# x = first_episode.find('span',  attrs={'class': 'ipl-rating-star__rating'}).text
# x

# %%
print(len(season_no_list))
print(len(episode_no_list))
print(len(episode_name_list))
print(len(episode_airdate_list))
print(len(episode_score_list))
print(len(episode_votes_list))
# Out:
# 59
# 59
# 59
# 59
# 59
# 59

# %%
simpsons = pd.DataFrame({
    'season_no': season_no_list,
    'episode_no': episode_no_list,
    'episode_name': episode_name_list,
    'episode_airdate': episode_airdate_list,
    'episode_score': episode_score_list,
    'episode_votes': episode_votes_list
})

simpsons
# Out:
#     season_no  episode_no                                       episode_name  \
# 0           1           1                  Simpsons Roasting on an Open Fire
# 1           1           2                                    Bart the Genius
# 2           1           3                                    Homer's Odyssey
# 3           1           4                      There's No Disgrace Like Home
# 4           1           5                                   Bart the General
# 5           1           6                                       Moaning Lisa
# 6           1           7                           The Call of the Simpsons
# 7           1           8                                  The Telltale Head
# 8           1           9                              Life on the Fast Lane
# 9           1          10                                  Homer's Night Out
# 10          1          11                                The Crepes of Wrath
# ...

# %%
simpsons.to_excel('simpsons.xlsx')

# %%
url = 'https://www.imdb.com/search/title-text/?plot=lgbt'
response_imdb = requests.get(url)
page = BeautifulSoup(response_imdb.content)
tile = page.findAll('div', attrs={'class': 'lister-item-content'})

# %%
# print(tile)

# %%
first_entry = tile[0]
# print(first_entry)

first_entry_name = first_entry.a.text
print(first_entry_name)
# Out:
# 50 Years of Fabulous

# %%
# Out:
# []
